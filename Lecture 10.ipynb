# %%
import pandas as pd
import numpy as np

# %%
data = np.random.randint(10, 20, (10,5))

# %%
df = pd.DataFrame(data, columns=list("ABCDE"))

# %%
df
# Out:
#     A   B   C   D   E
# 0  11  19  13  14  19
# 1  19  15  10  14  19
# 2  14  11  13  15  14
# 3  19  12  12  15  10
# 4  13  14  12  17  16
# 5  13  17  12  12  13
# 6  19  19  17  19  13
# 7  17  18  12  16  15
# 8  13  11  16  12  18
# 9  17  19  10  18  19

# %%
df["A"]
# Out:
# 0    11
# 1    19
# 2    14
# 3    19
# 4    13
# 5    13
# 6    19
# 7    17
# 8    13
# 9    17
# Name: A, dtype: int64

# %%
df[["A", "C"]]
# Out:
#     A   C
# 0  11  13
# 1  19  10
# 2  14  13
# 3  19  12
# 4  13  12
# 5  13  12
# 6  19  17
# 7  17  12
# 8  13  16
# 9  17  10

# %%
# It's based on name, hence it include 5th row

df.loc[0:5]
# Out:
#     A   B   C   D   E
# 0  11  19  13  14  19
# 1  19  15  10  14  19
# 2  14  11  13  15  14
# 3  19  12  12  15  10
# 4  13  14  12  17  16
# 5  13  17  12  12  13

# %%
# It's based on index hence it ecludes last one

df.iloc[0:5]
# Out:
#     A   B   C   D   E
# 0  11  19  13  14  19
# 1  19  15  10  14  19
# 2  14  11  13  15  14
# 3  19  12  12  15  10
# 4  13  14  12  17  16

# %%
# Name based range, 

df.loc[0:5, ["A", "C"]]
# Out:
#     A   C
# 0  11  13
# 1  19  10
# 2  14  13
# 3  19  12
# 4  13  12
# 5  13  12

# %%
df.loc[0:5, "C":"A":-1]
# Out:
#     C   B   A
# 0  13  19  11
# 1  10  15  19
# 2  13  11  14
# 3  12  12  19
# 4  12  14  13
# 5  12  17  13

# %%
df["A"] > 15
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8    False
# 9     True
# Name: A, dtype: bool

# %%
df.loc[df["A"] > 15]
# Out:
#     A   B   C   D   E
# 1  19  15  10  14  19
# 3  19  12  12  15  10
# 6  19  19  17  19  13
# 7  17  18  12  16  15
# 9  17  19  10  18  19

# %%
df.loc[df["A"] > 15, [True, True, False, True, False]]
# Out:
#     A   B   D
# 1  19  15  14
# 3  19  12  15
# 6  19  19  19
# 7  17  18  16
# 9  17  19  18

# %%
df.loc[:, [True, True, False, True, False]]
# Out:
#     A   B   D
# 0  11  19  14
# 1  19  15  14
# 2  14  11  15
# 3  19  12  15
# 4  13  14  17
# 5  13  17  12
# 6  19  19  19
# 7  17  18  16
# 8  13  11  12
# 9  17  19  18

# %% [markdown]
# # Index Locate

# %%
df.iloc[:3]
# Out:
#     A   B   C   D   E
# 0  11  19  13  14  19
# 1  19  15  10  14  19
# 2  14  11  13  15  14

# %%
df.iloc[[3,5]]
# Out:
#     A   B   C   D   E
# 3  19  12  12  15  10
# 5  13  17  12  12  13

# %%
out
# Out:
#     A   B   D
# 1  19  15  14
# 3  19  12  15
# 6  19  19  19
# 7  17  18  16
# 9  17  19  18

# %%
out.iloc[1:3]
# Out:
#     A   B   D
# 3  19  12  15
# 6  19  19  19

# %%
out.iloc[[1,0,1,1]]
# Out:
#     A   B   D
# 3  19  12  15
# 1  19  15  14
# 3  19  12  15
# 3  19  12  15

# %%
out.mean(axis = 1)
# Out:
# 1    16.000000
# 3    15.333333
# 6    19.000000
# 7    17.000000
# 9    18.000000
# dtype: float64

# %%
out.mean()
# Out:
# A    18.2
# B    16.6
# D    16.4
# dtype: float64

# %%
out.describe()
# Out:
#                A         B          D
# count   5.000000   5.00000   5.000000
# mean   18.200000  16.60000  16.400000
# std     1.095445   3.04959   2.073644
# min    17.000000  12.00000  14.000000
# 25%    17.000000  15.00000  15.000000
# 50%    19.000000  18.00000  16.000000
# 75%    19.000000  19.00000  18.000000
# max    19.000000  19.00000  19.000000

# %%
out.iloc[:2, 0] = np.NaN

# %%
out
# Out:
#       A   B   D
# 1   NaN  15  14
# 3   NaN  12  15
# 6  19.0  19  19
# 7  17.0  18  16
# 9  17.0  19  18

# %%
out.isna()
# Out:
#        A      B      D
# 1   True  False  False
# 3   True  False  False
# 6  False  False  False
# 7  False  False  False
# 9  False  False  False

# %%
#threshold depicts if the series have more than this values as not na

out.dropna(axis=1, thresh=2)
# Out:
#       A   B   D
# 1   NaN  15  14
# 3   NaN  12  15
# 6  19.0  19  19
# 7  17.0  18  16
# 9  17.0  19  18

# %%
out.dropna(axis=1, thresh=4)
# Out:
#     B   D
# 1  15  14
# 3  12  15
# 6  19  19
# 7  18  16
# 9  19  18

# %%
df.apply(print)
# Out:
# 0    11
# 1    19
# 2    14
# 3    19
# 4    13
# 5    13
# 6    19
# 7    17
# 8    13
# 9    17
# Name: A, dtype: int64
# 0    19
# 1    15
# 2    11
# 3    12
# 4    14
# 5    17
# 6    19
# 7    18
# 8    11
# 9    19
# Name: B, dtype: int64
# 0    13
# 1    10
# 2    13
# 3    12
# 4    12
# 5    12
# 6    17
# 7    12
# 8    16
# 9    10
# Name: C, dtype: int64
# 0    14
# 1    14
# 2    15
# 3    15
# 4    17
# 5    12
# 6    19
# 7    16
# 8    12
# 9    18
# Name: D, dtype: int64
# 0    19
# 1    19
# 2    14
# 3    10
# 4    16
# 5    13
# 6    13
# 7    15
# 8    18
# 9    19
# Name: E, dtype: int64
# A    None
# B    None
# C    None
# D    None
# E    None
# dtype: object

# %%
def gen_output(row):
    row["sum"] = row.sum()
    return row

# %%
# row.copy is used so that it doesn't change the existing series of the dataframe

def gen_output(row):
    temp = row.copy()
    temp["output"] = row.sum()
    return temp

df.apply(gen_output, axis=1)
# Out:
#     A   B   C   D   E  K  output
# 0  22  38  26  28  38  6     158
# 1  38  30  20  28  38  6     160
# 2  28  22  26  30  28  4     138
# 3  38  24  24  30  20  2     138
# 4  26  28  24  34  32  2     146
# 5  26  34  24  24  26  4     138
# 6  38  38  34  38  26  2     176
# 7  34  36  24  32  30  6     162
# 8  26  22  32  24  36  4     144
# 9  34  38  20  36  38  6     172

# %%
def gen_double(row):
    row[:] = row * 2
    return row

df.apply(gen_double, axis=1)
# Out:
#     A   B   C   D   E  K
# 0  22  38  26  28  38  6
# 1  38  30  20  28  38  6
# 2  28  22  26  30  28  4
# 3  38  24  24  30  20  2
# 4  26  28  24  34  32  2
# 5  26  34  24  24  26  4
# 6  38  38  34  38  26  2
# 7  34  36  24  32  30  6
# 8  26  22  32  24  36  4
# 9  34  38  20  36  38  6

# %%
df.apply(gen_output, axis=1)
# Out:
#     A   B   C   D   E  sum
# 0  11  19  13  14  19   76
# 1  19  15  10  14  19   77
# 2  14  11  13  15  14   67
# 3  19  12  12  15  10   68
# 4  13  14  12  17  16   72
# 5  13  17  12  12  13   67
# 6  19  19  17  19  13   87
# 7  17  18  12  16  15   78
# 8  13  11  16  12  18   70
# 9  17  19  10  18  19   83

# %%
df["K"] = np.random.randint(1,4,10)

# %%
df
# Out:
#     A   B   C   D   E  K
# 0  11  19  13  14  19  3
# 1  19  15  10  14  19  3
# 2  14  11  13  15  14  2
# 3  19  12  12  15  10  1
# 4  13  14  12  17  16  1
# 5  13  17  12  12  13  2
# 6  19  19  17  19  13  1
# 7  17  18  12  16  15  3
# 8  13  11  16  12  18  2
# 9  17  19  10  18  19  3

# %%
df.groupby("K").mean()
# Out:
#            A      B          C     D     E
# K
# 1  17.000000  15.00  13.666667  17.0  13.0
# 2  13.333333  13.00  13.666667  13.0  15.0
# 3  16.000000  17.75  11.250000  15.5  18.0

# %%
df.groupby("K").sum()
# Out:
#     A   B   C   D   E
# K
# 1  51  45  41  51  39
# 2  40  39  41  39  45
# 3  64  71  45  62  72

# %%
df.loc[df["K"]== 2].sum(axis=0)
# Out:
# A    102
# B     90
# C     82
# D    102
# E     78
# K      6
# dtype: int64

# %% [markdown]
# # Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
m, c = 4, 0

# %%
X = np.linspace(10, 50, 100)     

noise = np.random.randn(100) * 20

# %%
y = m*X + c + noise

# %%
plt.scatter(X,y)

# %%
class CustomLinearReg:
    
    def __init__(self, lr=.1, iters=10):
        self.lr = lr
        self.iters = iters
    
    def fit(self, X, y):
        self.coef_ = np.random.random()
        
        errors = []
        for i in range(self.iters):
            error = self.gradient_decend(X, y)
            errors.append(error)
        
        return errors
    
    def gradient_decend(self, X, y):
        delta_coef, error = self.gradient(X, y)
#         print(delta_coef)
        self.coef_ += delta_coef
        return error
        
    def gradient(self, X, y):
        yh = self.hypo(X)
        dmsedm = np.mean(2 * (yh-y) * X)
        return -dmsedm * self.lr, np.mean((yh-y)**2)
        
    def hypo(self, X):
        return X * self.coef_

# %%
for i in range(5, 15):

    model = CustomLinearReg(lr=.0001*i, iters=30)
    errors = model.fit(X, y)
    
    plt.figure()
    plt.title(str(.0001*i))
    plt.plot(errors)
    plt.show()

# %%
model = CustomLinearReg(lr=.0001, iters=30)
errors = model.fit(X, y)

# %%
yh = model.hypo(X)

# %%
plt.scatter(X, y)
plt.scatter(X, yh)
