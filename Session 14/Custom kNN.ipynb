# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=100, centers=4, random_state=42)
plt.scatter(X[:, 0], X[:, 1], c=y)

point = np.array([-2, 0])

plt.scatter(X[:, 0], X[:, 1], c=y)
plt.scatter(point[0], point[1], s=60)

# %%
class kNN_Custom:
    
    def __init__(self):
        self.n_neighbours = n_neighbours
        
    def fit(self, X, y):
        self.__X = X
        sefl.__Y = y
        
    def predict_point(self, point):
        distances = np.sqrt(((self.__X - point)** 2).sum(axis = 1))
        distance_indices = distances.argsort()
        
        near_indices = distance_indices[:self.n_neighbours]
        
        votes = self.__y[near_indices]
        
        values, counts = np.unique(votes, counts=True)
