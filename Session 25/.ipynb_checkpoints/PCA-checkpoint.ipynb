# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_blobs
from sklearn.decomposition import PCA
import seaborn as sns
# Out:
# /home/ekta/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/ekta/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
X, y = make_blobs(centers=2, random_state=42)

# %%
model = PCA()

# %%
model.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
model.components_
# Out:
# array([[-0.73318049,  0.68003409],
#        [-0.68003409, -0.73318049]])

# %%
line1 = np.array([[0,0], model.components_[0]])
line2 = np.array([[0,0], model.components_[1]])

# %%
plt.figure(figsize=(6,6))
plt.plot(line1[:,0], line1[:,1])
plt.plot(line2[:,0], line2[:,1])
plt.show()

# %%
X.shape

# %%
model.components_.shape

# %%
X_mod = np.dot(X, model.components_.T)

# %%
X_regen[:10]

# %%
plt.imshow(X[5].reshape(28,28), cmap="gray")

# %%
plt.imshow(X_regen[5].reshape(28,28), cmap="gray")

# %%
model.transform(X).shape

# %%
data = np.load("../datasets/mnist/mnist_train_small.npy")

# %%
X, y = data[:,1:], data[:,0]

# %%
model = PCA(n_components=100)
model.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=100, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
X_gen = model.transform(X)

# %%
plt.scatter(X[:,0], X[:,1], c=y)

# %%
selected = y<3

# %%
selected
# Out:
# array([False, False, False, ...,  True, False, False])

# %%
y_selected = y[selected]

# %%
X_selected = X_gen[selected]

# %%
plt.scatter(X_selected[:, 0], X_selected[:,1], c = y_selected)

# %%
sns.scatterplot(X_selected[:, 0], X_selected[:,1], hue=y_selected)
